# %% [markdown]
# # **House Price Prediction**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold,cross_val_score,GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
df_train=pd.read_csv('/content/drive/MyDrive/Camerin DSML/Machine Test/House Price (Advanced)/train.csv')
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Camerin DSML/Machine Test/House Price (Advanced)/test.csv')
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# **Preprocessing**

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %% [markdown]
# **1. Handling Missing Values**

# %% [markdown]
# (i) Dropping Missing Values

# %%
# Training Data
for i in df_train:
  if df_train[i].isna().sum()!=0:
    print(i,df_train[i].isna().sum())
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 872
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df_train=df_train.drop(columns=['Id','MiscFeature','Fence','PoolQC','FireplaceQu','MasVnrType','Alley'])
df_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
# Testing Data
for i in df_test:
  if df_test[i].isna().sum()!=0:
    print(i,df_test[i].isna().sum())
# Out:
# MSZoning 4
# LotFrontage 227
# Alley 1352
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 894
# MasVnrArea 15
# BsmtQual 44
# BsmtCond 45
# BsmtExposure 44
# BsmtFinType1 42
# BsmtFinSF1 1
# BsmtFinType2 42
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# FireplaceQu 730
# GarageType 76
# GarageYrBlt 78
# GarageFinish 78
# GarageCars 1
# GarageArea 1
# GarageQual 78
# GarageCond 78
# PoolQC 1456
# Fence 1169
# MiscFeature 1408
# SaleType 1

# %%
df_test=df_test.drop(columns=['MiscFeature','Fence','PoolQC','FireplaceQu','MasVnrType','Alley'])
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %% [markdown]
# (ii) Filling Missing Values

# %%
# Training Data
for i in df_train:
  if df_train[i].isna().sum()!=0:
    print(i,df_train[i].isna().sum())
# Out:
# LotFrontage 259
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81

# %%
ob_train=[]
nu_train=[]
for i in df_train:
  if df_train[i].isna().sum()!=0:
     if df_train[i].dtype=='object':
       ob_train.append(i)
     else:
       nu_train.append(i)
print(f'Object Columns : \n {ob_train}')
print(f'Number of Object Columns : {len(ob_train)}')
print(f'\n Numeric Columns : \n {nu_train}')
print(f'Number of Numeric Columns : {len(nu_train)}')
# Out:
# Object Columns :
#  ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
# Number of Object Columns : 10
#
#  Numeric Columns :
#  ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# Number of Numeric Columns : 3

# %%
df_train['LotFrontage']=df_train['LotFrontage'].fillna(df_train['LotFrontage'].mean())
df_train['GarageYrBlt']=df_train['GarageYrBlt'].fillna(df_train['GarageYrBlt'].mode())
df_train=df_train.dropna()

# %%
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
c=0
for i in df_train:
  if df_train[i].isna().sum()==0:
    c=0
  else:
    c+=1
if c==0:
  print('Missing values handled')
else:
  print('There are missing values')
# Out:
# Missing values handled

# %%
# Testing Data
for i in df_test:
  if df_test[i].isna().sum()!=0:
    print(i,df_test[i].isna().sum())
# Out:
# MSZoning 4
# LotFrontage 227
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrArea 15
# BsmtQual 44
# BsmtCond 45
# BsmtExposure 44
# BsmtFinType1 42
# BsmtFinSF1 1
# BsmtFinType2 42
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# GarageType 76
# GarageYrBlt 78
# GarageFinish 78
# GarageCars 1
# GarageArea 1
# GarageQual 78
# GarageCond 78
# SaleType 1

# %%
ob_test=[]
nu_test=[]
for i in df_test:
  if df_test[i].isna().sum()!=0:
    if df_test[i].dtype=='object':
      ob_test.append(i)
    else:
      nu_test.append(i)
print(f'Object Columns : \n {ob_test}')
print(f'Number of Object Columns : {len(ob_test)}')
print(f'\nNumeric Columns : \n {nu_test}')
print(f'Number of Numeric Columns : {len(nu_test)}')
# Out:
# Object Columns :
#  ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'SaleType']
# Number of Object Columns : 16
#
# Numeric Columns :
#  ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea']
# Number of Numeric Columns : 11

# %% [markdown]
# **Numeric Values**

# %%
df_test['LotFrontage']=df_test['LotFrontage'].fillna(np.round(df_test['LotFrontage'].mean()))

# %%
df_test['MasVnrArea']=df_test['MasVnrArea'].fillna(np.round(df_test['MasVnrArea'].mean()))

# %%
df_test['BsmtFinSF1']=df_test['BsmtFinSF1'].fillna(np.round(df_test['BsmtFinSF1'].mean()))

# %%
df_test['BsmtFinSF2']=df_test['BsmtFinSF2'].fillna(np.round(df_test['BsmtFinSF2'].mean()))

# %%
df_test['BsmtUnfSF']=df_test['BsmtUnfSF'].fillna(np.round(df_test['BsmtUnfSF'].mean()))

# %%
df_test['TotalBsmtSF']=df_test['TotalBsmtSF'].fillna(np.round(df_test['TotalBsmtSF'].mean()))

# %%
df_test['BsmtFullBath']=df_test['BsmtFullBath'].fillna(np.round(df_test['BsmtFullBath'].mean()))

# %%
df_test['BsmtHalfBath']=df_test['BsmtHalfBath'].fillna(np.round(df_test['BsmtHalfBath'].mean()))

# %%
df_test['GarageYrBlt']=df_test['GarageYrBlt'].fillna(2005)

# %%
df_test['GarageCars']=df_test['GarageCars'].fillna(2.0)

# %%
df_test['GarageArea']=df_test['GarageArea'].fillna(np.round(df_test['GarageArea'].mean()))

# %% [markdown]
# **Object Values**

# %%
df_test['MSZoning']=df_test['MSZoning'].fillna('RL')

# %%
df_test['Utilities']=df_test['Utilities'].fillna('AllPubUtilities')

# %%
df_test['Exterior1st']=df_test['Exterior1st'].fillna('VinylSd')

# %%
df_test['Exterior2nd']=df_test['Exterior2nd'].fillna('VinylSd')

# %%
df_test['BsmtQual']=df_test['BsmtQual'].fillna('TA')

# %%
df_test['BsmtCond']=df_test['BsmtCond'].fillna('TA')

# %%
df_test['BsmtExposure']=df_test['BsmtExposure'].fillna('No')

# %%
df_test['BsmtFinType1']=df_test['BsmtFinType1'].fillna('Unf')

# %%
df_test['BsmtFinType2']=df_test['BsmtFinType2'].fillna('Unf')

# %%
df_test['KitchenQual']=df_test['KitchenQual'].fillna('TA')

# %%
df_test['Functional']=df_test['Functional'].fillna('Typ')

# %%
df_test['GarageType']=df_test['GarageType'].fillna('Attchd')

# %%
df_test['GarageFinish']=df_test['GarageFinish'].fillna('Unf')

# %%
df_test['GarageQual']=df_test['GarageQual'].fillna('TA')

# %%
df_test['GarageCond']=df_test['GarageCond'].fillna('Fa')

# %%
df_test['SaleType']=df_test['SaleType'].fillna('WD')

# %%
c=0
for i in df_test:
  if df_test[i].isna().sum()==0:
    c=0
  else:
    c+=1
if c==0:
  print('Missing values handled')
else:
  print('There are missing values')
# Out:
# Missing values handled

# %%
print(f'Shape of Training Data : {df_train.shape}')
print(f'Shape of Testing Data : {df_test.shape}')
# Out:
# Shape of Training Data : (1338, 74)
# Shape of Testing Data : (1459, 74)

# %% [markdown]
# **2. Label Encoding**

# %%
# Training Data
encoder=LabelEncoder()
for i in df_train:
  if df_train[i].dtype=='object':
    df_train[i]=encoder.fit_transform(df_train[i])
  print(i,df_train[i].dtype)
# Out:
# MSSubClass int64
# MSZoning int64
# LotFrontage float64
# LotArea int64
# Street int64
# LotShape int64
# LandContour int64
# Utilities int64
# LotConfig int64
# LandSlope int64
# Neighborhood int64
# Condition1 int64
# Condition2 int64
# BldgType int64
# HouseStyle int64
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle int64
# RoofMatl int64
# Exterior1st int64
# Exterior2nd int64
# MasVnrArea float64
# ExterQual int64
# ExterCond int64
# Foundation int64
# BsmtQual int64
# BsmtCond int64
# BsmtExposure int64
# BsmtFinType1 int64
# BsmtFinSF1 int64
# BsmtFinType2 int64
# BsmtFinSF2 int64
# BsmtUnfSF int64
# TotalBsmtSF int64
# Heating int64
# HeatingQC int64
# CentralAir int64
# Electrical int64
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath int64
# BsmtHalfBath int64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# KitchenAbvGr int64
# KitchenQual int64
# TotRmsAbvGrd int64
# ...

# %%
# Testing Data
for i in df_test:
  if df_test[i].dtype=='object':
    df_test[i]=encoder.fit_transform(df_test[i])
  print(i,df_test[i].dtype)
# Out:
# Id int64
# MSSubClass int64
# MSZoning int64
# LotFrontage float64
# LotArea int64
# Street int64
# LotShape int64
# LandContour int64
# Utilities int64
# LotConfig int64
# LandSlope int64
# Neighborhood int64
# Condition1 int64
# Condition2 int64
# BldgType int64
# HouseStyle int64
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle int64
# RoofMatl int64
# Exterior1st int64
# Exterior2nd int64
# MasVnrArea float64
# ExterQual int64
# ExterCond int64
# Foundation int64
# BsmtQual int64
# BsmtCond int64
# BsmtExposure int64
# BsmtFinType1 int64
# BsmtFinSF1 float64
# BsmtFinType2 int64
# BsmtFinSF2 float64
# BsmtUnfSF float64
# TotalBsmtSF float64
# Heating int64
# HeatingQC int64
# CentralAir int64
# Electrical int64
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath float64
# BsmtHalfBath float64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# KitchenAbvGr int64
# KitchenQual int64
# ...

# %% [markdown]
# **3. Train-Test Split**

# %%
x=df_train.drop(columns='SalePrice')
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# 0          0          4          0  ...           61              0
# 1          0          2          0  ...            0              0
# 2          0          4          0  ...           42              0
# 3          0          0          0  ...           35            272
# 4          0          2          0  ...           84              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
y=df_train['SalePrice']
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
scaler=StandardScaler()
for i in x:
  x[[i]]=scaler.fit_transform(x[[i]])
x.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea    Street  LotShape  \
# 0    0.093701 -0.038318    -0.254147 -0.218363  0.061245  0.772893
# 1   -0.876298 -0.038318     0.422953 -0.107067  0.061245  0.772893
# 2    0.093701 -0.038318    -0.118727  0.052620  0.061245 -1.341893
# 3    0.336201 -0.038318    -0.479847 -0.111906  0.061245 -1.341893
# 4    0.093701 -0.038318     0.603514  0.343926  0.061245 -1.341893
#
#    LandContour  Utilities  LotConfig  LandSlope  ...  OpenPorchSF  \
# 0     0.308907  -0.027349   0.612488  -0.228303  ...     0.202294
# 1     0.308907  -0.027349  -0.614322  -0.228303  ...    -0.731311
# 2     0.308907  -0.027349   0.612488  -0.228303  ...    -0.088501
# 3     0.308907  -0.027349  -1.841132  -0.228303  ...    -0.195636
# 4     0.308907  -0.027349  -0.614322  -0.228303  ...     0.554309
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea   MiscVal    MoSold  \
# 0      -0.349612  -0.118688    -0.283203 -0.071771 -0.084535 -1.605319
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=13)

# %% [markdown]
# **4. Cross Validation**

# %%
LR_score=cross_val_score(LinearRegression(),X=x,y=y,cv=5)
DT_score=cross_val_score(DecisionTreeRegressor(),X=x,y=y,cv=5)
RF_score=cross_val_score(RandomForestRegressor(),X=x,y=y,cv=5)
KN_score=cross_val_score(KNeighborsRegressor(),X=x,y=y,cv=5)
AD_score=cross_val_score(AdaBoostRegressor(),X=x,y=y,cv=5)
GB_score=cross_val_score(GradientBoostingRegressor(),X=x,y=y,cv=5)
XG_score=cross_val_score(XGBRegressor(),X=x,y=y,cv=5)
svm_score=cross_val_score(SVR(),X=x,y=y,cv=5)

# %%
print(f'Linear Regression : {np.round(np.mean(LR_score)*100,2)}%')
print(f'Decision Tree : {np.round(np.mean(DT_score)*100,2)}%')
print(f'Random Forest : {np.round(np.mean(RF_score)*100,2)}%')
print(f'KNN : {np.round(np.mean(KN_score)*100,2)}%')
print(f'Adaboost : {np.round(np.mean(AD_score)*100,2)}%')
print(f'Gradient Boost : {np.round(np.mean(GB_score)*100,2)}%')
print(f'XGB : {np.round(np.mean(XG_score)*100,2)}%')
print(f'SVM : {np.round(np.mean(svm_score)*100,2)}%')
# Out:
# Linear Regression : 78.3%
# Decision Tree : 69.58%
# Random Forest : 85.54%
# KNN : 73.94%
# Adaboost : 80.42%
# Gradient Boost : 88.17%
# XGB : 85.35%
# SVM : -5.49%

# %% [markdown]
# **5. Grid Search**

# %% [markdown]
# * Gradient Boost : 88.19%
# * XGB : 85.35%
# * Random Forest : 85.23%

# %%
Gb=GradientBoostingRegressor()
Gb_params=[{'max_depth':list(range(2,7)),'learning_rate':[i/100 for i in range(1,21)]}]

# %%
clf=GridSearchCV(Gb,Gb_params,cv=5,scoring='r2')
clf.fit(x_train,y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'learning_rate': 0.07, 'max_depth': 4}
# 0.887567466579932

# %% [markdown]
# {'learning_rate': 0.18, 'max_depth': 5}
#
# 0.8886877321657727

# %%
Xg=XGBRegressor()
Xg_params=[{'colsample_bytree':[i/10 for i in range(4,11)],'gamma':list(range(0,10))}]

# %%
clf=GridSearchCV(Xg,Xg_params,cv=5,scoring='r2')
clf.fit(x_train,y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'colsample_bytree': 0.4, 'gamma': 0}
# 0.870387852191925

# %% [markdown]
# {'colsample_bytree': 0.4, 'gamma': 0}
#
# 0.870387852191925

# %%
Rf=RandomForestRegressor(random_state=42)
Rf_params=[{'n_estimators':[150,300],'max_depth':[None,10,20]}]

# %%
clf=GridSearchCV(Rf,Rf_params,cv=5,scoring='r2')
clf.fit(x_train,y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'max_depth': None, 'n_estimators': 300}
# 0.8598820818322572

# %% [markdown]
# {'max_depth': None, 'n_estimators': 300}
#
# 0.8598820818322572

# %% [markdown]
# **6. Model Selection**

# %%
model=GradientBoostingRegressor(learning_rate=0.18,max_depth=5)
model.fit(x_train,y_train)

pred_y=model.predict(x_test)
pred_y
# Out:
# array([225731.59368263,  73087.20900651, 280767.17915923, 280037.74163147,
#        335387.431993  , 136459.09417296, 272168.79682404, 324478.48682924,
#        162899.74820739, 210364.59604123, 173196.29560681, 140853.96498208,
#        231313.61112612, 200286.38435719, 361676.41896536, 149499.7311694 ,
#        126385.01007891, 148752.67380867, 123338.18254256, 152161.15532433,
#        162462.27514508, 383560.741973  , 239630.81837268, 116152.91475936,
#        141281.21910137, 141024.7787004 , 152422.11115339, 170918.03028332,
#        136349.08211462, 225096.85523496, 122645.71678993, 117716.62578128,
#        121955.54333589, 130621.11278063, 180425.31040956, 272335.53266617,
#        318891.85381521, 274632.31497808, 226566.5296939 , 170944.21660489,
#        536032.73804283, 204147.75474518, 139012.82377455, 222081.95373153,
#        248990.81659598, 379730.42839504, 189873.20434149, 285282.90625356,
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.802077473503033

# %% [markdown]
# **7. Test Data**

# %%
df_test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     1461          20         2         80.0    11622       1         3
# 1     1462          20         3         81.0    14267       1         0
# 2     1463          60         3         74.0    13830       1         0
# 3     1464          60         3         78.0     9978       1         0
# 4     1465         120         3         43.0     5005       1         0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1454  2915         160         4         21.0     1936       1         3
# 1455  2916         160         4         21.0     1894       1         3
# 1456  2917          20         3        160.0    20000       1         3
# 1457  2918          85         3         62.0    10441       1         3
# 1458  2919          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
ID=df_test['Id']
df_test=df_test.drop(columns='Id')

# %%
p=[]
predicted=model.predict(df_test)
p=np.round(predicted)
print(p)
# Out:
# [587026. 521796. 659051. ... 495368. 329351. 653990.]

# %%
final=pd.DataFrame({
    'ID':ID,
    "SalePrice":p
})
final
# Out:
#         ID  SalePrice
# 0     1461   587026.0
# 1     1462   521796.0
# 2     1463   659051.0
# 3     1464   658429.0
# 4     1465   616244.0
# ...    ...        ...
# 1454  2915   409140.0
# 1455  2916   627352.0
# 1456  2917   495368.0
# 1457  2918   329351.0
# 1458  2919   653990.0
#
# [1459 rows x 2 columns]

# %%
final.to_csv('Submission.csv',index=False)

from google.colab import files
files.download("Submission.csv")
